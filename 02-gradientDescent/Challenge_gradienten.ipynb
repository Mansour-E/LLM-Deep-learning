# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import sympy as sym

import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
x = sym.symbols('x')
def f(x):
    return sym.cos(2*sym.pi*x) + x**2

#def df(x):
   # return sym.diff(sym.cos(2 * sym.pi * x) + x**2, x)
fx_expr = f(x)
df_expr = sym.diff(fx_expr, x_sym)


print('Via sympy:')
display(fx_expr)
display(df_expr)




f  = sym.lambdify(x_sym, fx_expr, 'numpy')
df= sym.lambdify(x_sym, df_expr, 'numpy')

# 3. Numerik
x_vals = np.linspace(-2, 2, 200)

# 4. Plotten
# WICHTIG: Hier f_numpy und df_numpy benutzen!
plt.plot(x_vals, f_numpy(x_vals), label='y')
plt.plot(x_vals, df_numpy(x_vals), label='dy')

plt.xlim(x_vals[0], x_vals[-1])
plt.xlabel('x')
plt.ylabel('f(X)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Via sympy:
# x**2 + cos(2*pi*x)
# 2*x - 2*pi*sin(2*pi*x)

# %%
x = np.linspace(-2,2,2001)
learning_rate = 0.001
training_epochs = 100000
local_minima = np.random.choice(x,1)
print(local_minima)

#gradient
for i in range(training_epochs):
    grad = df(local_minima)
    local_minima = local_minima - learning_rate*grad
local_minima
# Out:
# [0.042]
# array([0.47580245])
